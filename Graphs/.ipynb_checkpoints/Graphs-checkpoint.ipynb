# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('retail_may.csv')

# %%
data = df.sample(n=1000)
data2 = df.sample(n=2000)
#data = df.iloc[0:100, 1:3]

# %%
data.shape
# Out:
# (1000, 28)

# %%
data.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country', 'AcceptDiscount', 'NormalPrice',
#        'LenghtDiscount', 'day_of_week', 'PromotionDays', 'Elasticity',
#        'KindOfSale', 'Display', 'DisplayInStore', 'TypeofPromotion',
#        'TypeofProduct', 'CompetitionPressure', 'Seasonality', 'Category',
#        'Time', 'Date', 'Payment', 'Revenue', 'Clustering', 'Weather'],
#       dtype='object')

# %%
square = pd.crosstab(data.Country, data.Category)
idx = square.columns.union(square.index)
matrix_squared = square.reindex(index = idx, columns=idx, fill_value=0)
#matrix_squared.head(10)
G = nx.from_pandas_adjacency(matrix_squared)
G.name = 'Graph from pandas adjacency matrix'
print(nx.info(G))
#nx.draw(G)
# Out:
# Name: Graph from pandas adjacency matrix
# Type: Graph
# Number of nodes: 23
# Number of edges: 46
# Average degree:   4.0000

# %%
# Out:
# Name: Graph from pandas adjacency matrix
# Type: Graph
# Number of nodes: 23
# Number of edges: 46
# Average degree:   4.0000

# %%
df = pd.crosstab(df.Name_A, df.Name_B)
print (df)
Name_B  Ben  Chris  David
Name_A                   
Adam      1      1      0
Ben       0      1      0
Chris     0      0      1

df = pd.crosstab(df.Name_A, df.Name_B)
idx = df.columns.union(df.index)
df = df.reindex(index = idx, columns=idx, fill_value=0)
print (df)
       Adam  Ben  Chris  David
Adam      0    1      1      0
Ben       0    0      1      0
Chris     0    0      0      1
David     0    0      0      0

# %%
square.head(10)
# Out:
# CustomerID  12348.0  12377.0  12378.0  12379.0  12407.0  12415.0  12417.0  \
# InvoiceNo
# 536460            0        0        0        0        0        0        0
# 536528            0        0        0        0        0        0        0
# 536538            0        0        0        0        0        0        0
# 536612            0        0        0        0        0        0        0
# 536778            0        0        0        0        0        0        0
# 536796            0        0        0        0        0        0        0
# 536973            0        0        0        0        0        0        0
# 537144            0        0        0        0        0        0        0
# 537160            0        0        0        0        0        0        0
# 537214            0        0        0        0        0        0        0
#
# CustomerID  12420.0  12428.0  12433.0   ...     18118.0  18122.0  18125.0  \
# InvoiceNo                               ...
# ...

# %%
edges2 = edges = nx.convert_matrix.from_pandas_edgelist(data2, source='CustomerID', target='Category')
nx.draw(edges2)

# %%
edges = nx.convert_matrix.from_pandas_edgelist(data, source='CustomerID', target='Category')
nx.draw(edges)

# %%
nx.convert_matrix.from_numpy_array()

# %%
data
# Out:
#    StockCode                          Description
# 0     85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 1      71053                  WHITE METAL LANTERN
# 2     84406B       CREAM CUPID HEARTS COAT HANGER
# 3     84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 4     84029E       RED WOOLLY HOTTIE WHITE HEART.
# 5      22752         SET 7 BABUSHKA NESTING BOXES
# 6      21730    GLASS STAR FROSTED T-LIGHT HOLDER
# 7      22633               HAND WARMER UNION JACK
# 8      22632            HAND WARMER RED POLKA DOT
# 9      84879        ASSORTED COLOUR BIRD ORNAMENT
# 10     22745           POPPY'S PLAYHOUSE BEDROOM
# 11     22748            POPPY'S PLAYHOUSE KITCHEN
# 12     22749    FELTCRAFT PRINCESS CHARLOTTE DOLL
# 13     22310              IVORY KNITTED MUG COSY
# 14     84969   BOX OF 6 ASSORTED COLOUR TEASPOONS
# 15     22623        BOX OF VINTAGE JIGSAW BLOCKS
# 16     22622       BOX OF VINTAGE ALPHABET BLOCKS
# 17     21754             HOME BUILDING BLOCK WORD
# ...

# %%
data.shape
# Out:
# (100, 2)

# %%
G = nx.from_pandas_adjacency(data)
G.name = 'Graph from pandas adjacency matrix'
print(nx.info(G))
# Out:
# ---------------------------------------------------------------------------
# NetworkXError                             Traceback (most recent call last)
# <ipython-input-11-c1a368314328> in <module>()
# ----> 1 G = nx.from_pandas_adjacency(data)
#       2 G.name = 'Graph from pandas adjacency matrix'
#       3 print(nx.info(G))
#
# /anaconda3/lib/python3.6/site-packages/networkx/convert_matrix.py in from_pandas_adjacency(df, create_using)
#     178
#     179     A = df.values
# --> 180     G = from_numpy_matrix(A, create_using=create_using)
#     181     try:
#     182         df = df[df.index]
#
# /anaconda3/lib/python3.6/site-packages/networkx/convert_matrix.py in from_numpy_matrix(A, parallel_edges, create_using)
#     551     if n != m:
#     552         raise nx.NetworkXError("Adjacency matrix is not square.",
# --> 553                                "nx,ny=%s" % (A.shape,))
#     554     dt = A.dtype
#     555     try:
#
# ...

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country', 'AcceptDiscount', 'NormalPrice',
#        'LenghtDiscount', 'day_of_week', 'PromotionDays', 'Elasticity',
#        'KindOfSale', 'Display', 'DisplayInStore', 'TypeofPromotion',
#        'TypeofProduct', 'CompetitionPressure', 'Seasonality', 'Category',
#        'Time', 'Date', 'Payment', 'Revenue', 'Clustering', 'Weather'],
#       dtype='object')

# %%
customer_id = df.CustomerID.values
description = df.Description.values
country = df.Country.values
category = df.Category.values
clustering = df.Clustering.values

# %%
description
# Out:
# array(['WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN',
#        'CREAM CUPID HEARTS COAT HANGER', ...,
#        'HEART MIRROR ANTIQUE WHITE', 'RETROSPOT TEA SET CERAMIC 11 PC ',
#        ' I LOVE LONDON MINI BACKPACK'], dtype=object)

# %%
G.add_nodes_from(df['Description'], country = 'england')

# %%
nx.draw(G)

# %%
for column in df.iterrows:
    G.add_nodes_from(df['description'], country = 'england')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-3e557e13cbc1> in <module>()
# ----> 1 for column in df.iterrows:
#       2     G.add_nodes_from(df['description'], country = 'england')
#
# TypeError: 'method' object is not iterable

# %%
for row in df.iter:
    G.add_nodes_from(row, country = 'england')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-7a66fd48464b> in <module>()
#       1 for row in description:
# ----> 2     G.add_nodes_from(row, country = 'england')
#
# /anaconda3/lib/python3.6/site-packages/networkx/classes/graph.py in add_nodes_from(self, nodes_for_adding, **attr)
#     529
#     530         """
# --> 531         for n in nodes_for_adding:
#     532             # keep all this inside try/except because
#     533             # CPython throws TypeError on n not in self._node,
#
# TypeError: 'float' object is not iterable

# %%
for a, b in zip(customer_id, description):
    G.add_nodes_from([a, b])

# %%
G=nx.Graph()

#extract and add AGE_GROUP nodes in graph
f1 = csv.reader(open("user_agegroup.txt","rb"))
for row in f1: 
    G.add_nodes_from(row, color = 'blue')

#extract and add COUNTRY nodes in graph
f2 = csv.reader(open('user_country.txt','rb'))
for row in f2:
    G.add_nodes_from(row, color = 'red') 

#extract and add USER_ID nodes in graph
f3 = csv.reader(open('user_id.txt','rb'))
for row in f3:
    G.add_nodes_from(row, color = 'yellow')

f4 = csv.reader(open('id,agegroup.txt','rb'))
for row in f4:
    if len(row) == 2 : # add an edge only if both values are provided
        G.add_edge(row[0],row[1])

f5 = csv.reader(open('id,country.txt','rb'))

for row in f5:
    if len(row) == 2 : # add an edge only if both values are provided
        G.add_edge(row[0],row[1])

# %%
# Author: Aric Hagberg <aric.hagberg@gmail.com>

#    Copyright (C) 2011-2018 by
#    Aric Hagberg <hagberg@lanl.gov>
#    Dan Schult <dschult@colgate.edu>
#    Pieter Swart <swart@lanl.gov>
#    All rights reserved.
#    BSD license.
import json

import flask
import networkx as nx
from networkx.readwrite import json_graph

G = nx.barbell_graph(6, 3)
# this d3 example uses the name attribute for the mouse-hover value,
# so add a name to each node
for n in G:
    G.nodes[n]['name'] = n
# write json formatted data
d = json_graph.node_link_data(G)  # node-link format to serialize
# write json
json.dump(d, open('force/force.json', 'w'))
print('Wrote node-link JSON data to force/force.json')

# Serve the file over http to allow for cross origin requests
app = flask.Flask(__name__, static_folder="force")

@app.route('/<path:path>')
def static_proxy(path):
    return app.send_static_file(path)

print('\nGo to http://localhost:8000/force.html to see the example\n')
app.run(port=8000)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-39-4a2a2b6a16f4> in <module>()
#      21 d = json_graph.node_link_data(G)  # node-link format to serialize
#      22 # write json
# ---> 23 json.dump(d, open('force/force.json', 'w'))
#      24 print('Wrote node-link JSON data to force/force.json')
#      25
#
# FileNotFoundError: [Errno 2] No such file or directory: 'force/force.json'
