# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('retail_may.csv')

# %%
df.dropna(inplace=True)

# %%
df.to_csv('retail_june.csv', sep=',')

# %%
df.isnull().sum()
# Out:
# InvoiceNo              0
# StockCode              0
# Description            0
# Quantity               0
# InvoiceDate            0
# UnitPrice              0
# CustomerID             0
# Country                0
# AcceptDiscount         0
# NormalPrice            0
# LenghtDiscount         0
# day_of_week            0
# PromotionDays          0
# Elasticity             0
# KindOfSale             0
# Display                0
# DisplayInStore         0
# TypeofPromotion        0
# TypeofProduct          0
# CompetitionPressure    0
# Seasonality            0
# Category               0
# Time                   0
# Date                   0
# Payment                0
# Revenue                0
# Clustering             0
# Weather                0
# dtype: int64

# %%
X = df.drop(['AcceptDiscount'], axis=1)

# %%
X = X.select_dtypes(include=['int', 'float'])
y = np.array(df[['AcceptDiscount']]).ravel()

# %%
y
# Out:
# array([0, 1, 0, ..., 1, 1, 1])

# %%
X.columns
# Out:
# Index(['Quantity', 'UnitPrice', 'CustomerID', 'NormalPrice', 'LenghtDiscount',
#        'PromotionDays', 'Elasticity', 'KindOfSale', 'Display',
#        'DisplayInStore', 'TypeofPromotion', 'TypeofProduct',
#        'CompetitionPressure', 'Seasonality', 'Revenue', 'Clustering'],
#       dtype='object')

# %% [markdown]
#      """
#         Parameters
#         -----------
#         treatment : array-like
#             binary treatment assignment
#         covariates : pd.DataFrame
#             covariates, one row for each observation
#         """

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from pscore_match.pscore import PropensityScore

# %%
y = df[['AcceptDiscout']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-d2d393349bc4> in <module>()
# ----> 1 y = df[['AcceptDiscout']]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2677         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2678             # either boolean or fancy integer index
# -> 2679             return self._getitem_array(key)
#    2680         elif isinstance(key, DataFrame):
#    2681             return self._getitem_frame(key)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2721             return self._take(indexer, axis=0)
#    2722         else:
# -> 2723             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2724             return self._take(indexer, axis=1)
#    2725
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1325                 if mask.any():
#    1326                     raise KeyError('{mask} not in index'
# -> 1327                                    .format(mask=objarr[mask]))
#    1328
#    1329                 return com._values_from_object(indexer)
#
# KeyError: "['AcceptDiscout'] not in index"

# %%
y
# Out:
# ['AcceptDiscount']

# %%
treatment = y
covariates = X

# %%
covariates
# Out:
#         Quantity  UnitPrice  CustomerID  NormalPrice  LenghtDiscount  \
# 0              6       2.55     17850.0    14.795989        8.162408
# 1              6       3.39     17850.0     1.497314        8.415264
# 2              8       2.75     17850.0     6.846211        1.753776
# 3              6       3.39     17850.0     1.825050        2.214386
# 4              6       3.39     17850.0    10.688266        4.782673
# 5              2       7.65     17850.0    13.595531        3.471170
# 6              6       4.25     17850.0     8.697515        5.699631
# 7              6       1.85     17850.0     6.550380        3.838285
# 8              6       1.85     17850.0     5.843938        3.333459
# 9             32       1.69     13047.0     7.945071        3.825552
# 10             6       2.10     13047.0     3.838989        9.708583
# 11             6       2.10     13047.0     4.257777        9.440400
# 12             8       3.75     13047.0     7.934462        5.180662
# 13             6       1.65     13047.0     4.367577        5.940750
# 14             6       4.25     13047.0    13.939915        6.772174
# 15             3       4.95     13047.0     2.579155        2.552955
# %%
pscore = PropensityScore(treatment, covariates).compute()

# %%
from pscore_match.match import Match, whichMatched
from scipy.stats import gaussian_kde
import matplotlib.pyplot as plt
pairs = Match(treatment, pscore)
pairs.create(method='many-to-one', many_method='knn', k=5, replace=True)

# %%
print(pairs.create(method='many-to-one', many_method='knn', k=5, replace=True))
# Out:
# None

# %%
covariates = np.array(covariates)

# %%
data_matched = whichMatched(pairs, pd.DataFrame({'pscore': pscore, 'treatment' :treatment}))

# %%
data_matched
# Out:
#           pscore  treatment
# 0       0.497364          0
# 1       0.540520          1
# 1       0.540520          1
# 2       0.553288          0
# 3       0.433216          1
# 3       0.433216          1
# 3       0.433216          1
# 3       0.433216          1
# 3       0.433216          1
# 3       0.433216          1
# 3       0.433216          1
# 3       0.433216          1
# 4       0.543609          0
# 5       0.519622          1
# 5       0.519622          1
# 5       0.519622          1
# 5       0.519622          1
# 5       0.519622          1
# 5       0.519622          1
# 5       0.519622          1
# 5       0.519622          1
# 5       0.519622          1
# 6       0.561966          1
# 6       0.561966          1
# 6       0.561966          1
# 7       0.458180          1
# 7       0.458180          1
# 7       0.458180          1
# 7       0.458180          1
# 8       0.466822          0
# ...          ...        ...
# 284257  0.397373          1
# 284257  0.397373          1
# 284257  0.397373          1
# 284257  0.397373          1
# 284257  0.397373          1
# 284257  0.397373          1
# 284257  0.397373          1
# 284257  0.397373          1
# 284257  0.397373          1
# 284257  0.397373          1
# 284257  0.397373          1
# 284257  0.397373          1
# 284257  0.397373          1
# 284257  0.397373          1
# 284257  0.397373          1
# 284257  0.397373          1
# 284257  0.397373          1
# 284257  0.397373          1
# 284257  0.397373          1
# 284257  0.397373          1
# 284257  0.397373          1
# 284258  0.521027          1
# 284258  0.521027          1
# 284258  0.521027          1
# 284259  0.499887          1
# 284259  0.499887          1
# 284259  0.499887          1
# 284259  0.499887          1
# 284259  0.499887          1
# 284259  0.499887          1
#
# [851916 rows x 2 columns]

# %%
a = PropensityScore(y_train, X_train)

# %%
match = a.compute()

# %%
X_train.shape
# Out:
# (190454, 16)

# %%
match.shape
# Out:
# (190454,)

# %%
match.min()
# Out:
# 0.27938932106472514

# %%
match.max()
# Out:
# 0.6923109342462814

# %%
match.argmin
# Out:
# <function ndarray.argmin>

# %%
#from pscore_match.data import gerber_green_imai
#from pscore_match.pscore import PropensityScore
from pscore_match.match import Match, whichMatched
from scipy.stats import gaussian_kde
import matplotlib.pyplot as plt
#import numpy as np
#import pandas as pd

imai = gerber_green_imai()

# Create interaction terms
imai['PERSONS1_VOTE961'] = (imai.PERSONS==1)*imai.VOTE961
imai['PERSONS1_NEW'] = (imai.PERSONS==1)*imai.NEW
treatment = np.array(imai.PHNC1)
cov_list = ['PERSONS', 'VOTE961', 'NEW', 'MAJORPTY', 'AGE', 'WARD', 'AGE2',
                            'PERSONS1_VOTE961', 'PERSONS1_NEW']
covariates = imai[cov_list]
pscore = PropensityScore(treatment, covariates).compute()

pairs = Match(treatment, pscore)
pairs.create(method='many-to-one', many_method='knn', k=5, replace=True)
data_matched = whichMatched(pairs, pd.DataFrame({'pscore': pscore, 'treatment' :treatment, 'voted':imai.VOTED98}))
